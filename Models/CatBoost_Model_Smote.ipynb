# %% [markdown]
# # CatBoost Model for Ethereum Fraud Detection
# # This notebook implements the **CatBoost (Categorical Boosting)** algorithm.
# # CatBoost is a high-performance gradient boosting library known for:
# # 1. Being extremely fast and efficient.
# # 2. Handling data patterns very well with less need for hyperparameter tuning.
# # 3. Often outperforming XGBoost and LightGBM on tabular data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import (confusion_matrix, accuracy_score, precision_score,
                             recall_score, f1_score, roc_auc_score, classification_report)
from catboost import CatBoostClassifier

# %% [markdown]
# # 2. LOAD DATA
# # We use the Time-Series version of the dataset as it contains the richest features.

# %%
file_path = '../Data/address_data_combined_ts.csv'
df = pd.read_csv(file_path)

print(f"Data Loaded. Shape: {df.shape}")
df.head()
# Out:
# Data Loaded. Shape: (13920, 24)
#                                       Address  FLAG  Avg min between sent tnx  \
# 0  0x87d884aaa6ff9e9b6014631b0abae80b53953fb8     1                   5151.68
# 1  0xd42393df90d582bd8a5493171f0173e3a017d391     1                   1179.02
# 2  0x3025c36d8a9620d3df89e9e9b1acbdfd639a6f37     1                    361.73
# 3  0x6309f709faad518fc158af4c14edfa7b06424770     1                      0.00
# 4  0x3d020954e30c3d40b7f0c533cf198bc10dd45a49     1                  14280.60
#
#    Avg min between received tnx  Time Diff between first and last (Mins)  \
# 0                      15159.08                                 71235.62
# 1                       1124.89                                 25126.45
# 2                          0.00                                   723.47
# 3                          0.00                                     0.00
# 4                       1479.86                                 45357.57
#
#    Unique Received From Addresses  min value received  max value received   \
# 0                               1            0.010000             0.020000
# 1                              13            0.000000             0.750000
# 2                               1            4.999916             4.999916
# 3                               0            0.000000             0.000000
# 4                              21            0.035000             0.200000
#
#    avg val received  min val sent  ...  \
# 0          0.013367      0.000000  ...
# 1          0.176667      0.145000  ...
# 2          4.999916      2.490000  ...
# 3          0.000000      0.000000  ...
# 4          0.099286      2.084658  ...
#
#    adjusted_eth_value__absolute_sum_of_changes  \
# 0                                     0.129900
# 1                                     7.669778
# 2                                     7.508992
# 3                                     0.000000
# 4                                     3.404658
#
#    adjusted_eth_value__mean_abs_change  \
# 0                             0.008119
# 1                             0.365228
# 2                             3.754496
# 3                             0.000000
# 4                             0.162127
#
#    adjusted_eth_value__energy_ratio_by_chunks__num_segments_10__segment_focus_0  \
# 0                                           0.358576
# 1                                           0.020237
# 2                                           0.666738
# 3                                           0.000000
# 4                                           0.006660
#
#    adjusted_eth_value__sum_values  adjusted_eth_value__abs_energy  \
# 0                        0.032100                        0.001400
# 1                       -0.284889                        3.335466
# 2                        0.000840                       37.494722
# 3                        0.000000                        0.000000
# 4                        0.000342                        4.594823
#
#    adjusted_eth_value__ratio_value_number_to_time_series_length  \
# 0                                           0.470588
# 1                                           0.409091
# 2                                           1.000000
# 3                                           0.000000
# 4                                           0.409091
#
#    adjusted_eth_value__quantile__q_0.1  adjusted_eth_value__count_below__t_0  \
# 0                            -0.000000                              0.647059
# 1                            -0.267421                              0.363636
# 2                            -2.505261                              0.666667
# 3                             0.000000                              0.000000
# 4                             0.050000                              0.045455
#
#    adjusted_eth_value__count_above__t_0  adjusted_eth_value__median
# 0                              0.941176                       0.000
# 1                              0.681818                       0.150
# 2                              0.333333                      -2.490
# 3                              0.000000                       0.000
# 4                              0.954545                       0.085
#
# [5 rows x 24 columns]

# %% [markdown]
# # 3. DATA PREPROCESSING
#
# # Define X (features) and y (target)
# # We drop 'Address' (ID), 'FLAG' (Target), and 'Unnamed: 0' if it exists.

# %%
cols_to_drop = ['Address', 'FLAG']
if 'Unnamed: 0' in df.columns:
    cols_to_drop.append('Unnamed: 0')

X = df.drop(columns=cols_to_drop)
y = df['FLAG']

# Split Data (70% Train, 30% Test) - Matching the other models' split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

print(f"Training Shape: {X_train.shape}")
print(f"Testing Shape: {X_test.shape}")
# Out:
# Training Shape: (9744, 22)
# Testing Shape: (4176, 22)

# %% [markdown]
# # 4. FEATURE ENGINEERING (Log Transform)
# # We apply log transformation to skewed columns to help the model learn better.
# # This matches the logic used in the XGBoost and LightGBM notebooks.

# %%
columns_to_log = [
    'Avg min between sent tnx', 'Avg min between received tnx',
    'Time Diff between first and last (Mins)', 'Unique Received From Addresses',
    'min value received', 'max value received ', 'avg val received',
    'min val sent', 'avg val sent',
    'total transactions (including tnx to create contract',
    'total ether received', 'total ether balance',
    'adjusted_eth_value__absolute_sum_of_changes',
    'adjusted_eth_value__mean_abs_change',
    'adjusted_eth_value__energy_ratio_by_chunks__num_segments_10__segment_focus_0',
    'adjusted_eth_value__sum_values', 'adjusted_eth_value__abs_energy',
    'adjusted_eth_value__ratio_value_number_to_time_series_length',
    'adjusted_eth_value__quantile__q_0.1', 'adjusted_eth_value__count_below__t_0',
    'adjusted_eth_value__count_above__t_0', 'adjusted_eth_value__median'
]

# %% [markdown]
# # Apply Log Transform (handling zeros safely)

# %%
for c in columns_to_log:
    if c in X_train.columns:
        X_train[c] = X_train[c].apply(lambda x: np.log(x) if x > 0 else 0)
        X_test[c] = X_test[c].apply(lambda x: np.log(x) if x > 0 else 0)

# %%
# --- NOUVELLE CELLULE (À placer APRÈS la cellule #4 Log Transform) ---
from imblearn.over_sampling import SMOTE
from collections import Counter

# 1. Vérification AVANT SMOTE
print(f"Distribution AVANT SMOTE (mais après Log) : {Counter(y_train)}")
print(f"Taille X_train : {X_train.shape}")

# 2. Application de SMOTE
# Les données sont déjà transformées par le Log (Cellule #4), donc SMOTE fonctionnera mieux !
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# 3. Mise à jour des variables
X_train = X_train_resampled
y_train = y_train_resampled

# 4. Vérification APRÈS
print("-" * 30)
print(f"Distribution APRÈS SMOTE : {Counter(y_train)}")
print(f"Nouvelle Taille X_train : {X_train.shape}")
# Out:
# Distribution AVANT SMOTE (mais après Log) : Counter({0: 5346, 1: 4398})
# Taille X_train : (9744, 22)
# ------------------------------
# Distribution APRÈS SMOTE : Counter({1: 5346, 0: 5346})
# Nouvelle Taille X_train : (10692, 22)

# %% [markdown]
# # 5. SCALING
# # We use MinMaxScaler to squash values between 0 and 1.

# %%
scaler = MinMaxScaler()

# %% [markdown]
# # Fit on training data, transform both

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # 6. MODEL DEFINITION & TRAINING
# # We initialize CatBoost with parameters similar to the other high-performing models.
# # verbose=0 keeps the output clean (suppresses the training log).

# %%
cat_model = CatBoostClassifier(
    iterations=1000,         # Number of trees (similar to n_estimators)
    learning_rate=0.05,      # Step size
    depth=6,                 # Depth of trees
    l2_leaf_reg=3,           # Regularization to prevent overfitting
    loss_function='Logloss', # Binary Classification objective
    eval_metric='AUC',       # Optimize for AUC
    random_seed=42,
    verbose=0                # Set to True if you want to see training progress
)

print("Training CatBoost Model...")
cat_model.fit(X_train_scaled, y_train)
print("✅ Training Complete.")
# Out:
# Training CatBoost Model...
# ✅ Training Complete.

# %% [markdown]
# # 7. EVALUATION
# # Make predictions

# %%
y_pred = cat_model.predict(X_test_scaled)
y_pred_proba = cat_model.predict_proba(X_test_scaled)[:, 1]

# %% [markdown]
# # Calculate Metrics

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_proba)

# %% [markdown]
# # 8. CONFUSION MATRIX VISUALIZATION

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('CatBoost Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()

# %% [markdown]
# # Create dataframe for plotting

# %%
# --- 1. ENTRAÎNEMENT (Pour définir la variable 'model') ---
from catboost import CatBoostClassifier

# On définit les paramètres (les mêmes que d'habitude)
cat_params = {
    'iterations': 1000,
    'learning_rate': 0.05,
    'depth': 6,
    'eval_metric': 'AUC',
    'verbose': 0,
    'random_seed': 42
}

# CRUCIAL : On crée la variable 'model' ici
model = CatBoostClassifier(**cat_params)

print("⏳ Entraînement en cours (Training)...")
model.fit(X_train, y_train)
print("✅ Modèle entraîné et variable 'model' créée !")

# --- 2. RÉCUPÉRATION DES IMPORTANCES ---
importance = model.feature_importances_
feature_names = X.columns
fi_df = pd.DataFrame({'Feature': feature_names, 'Importance': importance})
fi_df = fi_df.sort_values(by='Importance', ascending=False).head(10)

# --- 3. AFFICHAGE DU GRAPHIQUE ---
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.barplot(
    x='Importance',
    y='Feature',
    hue='Feature',
    data=fi_df,
    palette='viridis',
    legend=False
)
plt.title('Top 10 Features (CatBoost)')
plt.show()
# Out:
# ⏳ Entraînement en cours (Training)...
# ✅ Modèle entraîné et variable 'model' créée !

# %%
# --- ÉVALUATION SUR LE TEST SET ---
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score

# 1. Faire des prédictions
y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:, 1]

# 2. Afficher les scores
print("--- RÉSULTATS DU CATBOOST ---")
print(f"Accuracy : {accuracy_score(y_test, y_pred):.4f}")
print(f"ROC-AUC  : {roc_auc_score(y_test, y_prob):.4f}")
print("\nRapport détaillé :")
print(classification_report(y_test, y_pred))
# Out:
# --- RÉSULTATS DU CATBOOST ---
# Accuracy : 0.9380
# ROC-AUC  : 0.9864
#
# Rapport détaillé :
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94      2291
#            1       0.93      0.94      0.93      1885
#
#     accuracy                           0.94      4176
#    macro avg       0.94      0.94      0.94      4176
# weighted avg       0.94      0.94      0.94      4176
